# %% [markdown]
# **IMPORT STATEMENTS AND DATA EXPLORATION**

# %%
import pandas as pd
import plotly.express as px

# %%
df_apps = pd.read_csv("/content/apps.csv")

# %%
df_apps.shape
print("No of columns = 12")
print("No of rows = 10841")
# Out:
# No of columns = 12
# No of rows = 10841

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                                     App            Category  \
# 9079  Lumosity: #1 Brain Games & Cognitive Training App           EDUCATION
# 2447                             EU Flag Live Wallpaper     PERSONALIZATION
# 4680                   Anime et Manga Amino en Français              SOCIAL
# 4926                     Free Meditation - Take a Break  HEALTH_AND_FITNESS
# 6432                   Mobile Doc Scanner (MDScan) Lite            BUSINESS
#
#       Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 9079     4.2   215301      6.95  10,000,000  Free     0       Everyone
# 2447     NaN       19      2.30       1,000  Free     0       Everyone
# 4680     4.8     3782     63.00      50,000  Free     0           Teen
# 4926     4.2     1608     39.00     100,000  Free     0       Everyone
# 6432     4.2    46505     19.00   1,000,000  Free     0       Everyone
#
#                 Genres    Last_Updated         Android_Ver
# ...

# %%
df_apps.drop(['Last_Updated' ,'Android_Ver'], axis=1)
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME     4.5
# 10837                                Subway Surfers             GAME     4.5
# 10838                                Subway Surfers             GAME     4.5
# 10839                                Subway Surfers             GAME     4.5
# 10840                                Subway Surfers             GAME     4.5
#
# ...

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9365, 12)

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App','Type','Price'])
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL     4.5  66577313       5.3  1,000,000,000  Free
#
#       Price Content_Rating  Genres   Last_Updated         Android_Ver
# 10806     0           Teen  Social  July 31, 2018  Varies with device

# %%
df_apps_clean.shape
# Out:
# (8197, 12)

# %% [markdown]
# **Preliminary Exploration: The Highest Ratings, Most Reviews, and Largest Size**

# %%
highest_rated_index = df_apps_clean['Rating'].idxmax()
highest_rated_App = df_apps_clean['App'].loc[highest_rated_index]
print(f"The highest rated app is {highest_rated_App}")
# Out:
# The highest rated app is KBA-EZ Health Guide

# %%
df_apps_clean.loc[highest_rated_index]
# Out:
# App               KBA-EZ Health Guide
# Category                      MEDICAL
# Rating                            5.0
# Reviews                             4
# Size_MBs                         25.0
# Installs                            1
# Type                             Free
# Price                               0
# Content_Rating               Everyone
# Genres                        Medical
# Last_Updated           August 2, 2018
# Android_Ver              4.0.3 and up
# Name: 21, dtype: object

# %%
print("The problem with finding the highest rated app using the rating parameter is that a lot of applications have a very few number of reviews. Hence the average rating is high.")
# Out:
# The problem with finding the highest rated app using the rating parameter is that a lot of applications have a very few number of reviews. Hence the average rating is high.

# %%
highest_size_index = df_apps_clean['Size_MBs'].idxmax()
highest_size_App = df_apps_clean['App'].loc[highest_size_index]
print(f"The highest size app is {highest_size_App}")
# Out:
# The highest size app is Navi Radiography Pro

# %%
df_apps_clean.loc[highest_size_index]
# Out:
# App               Navi Radiography Pro
# Category                       MEDICAL
# Rating                             4.7
# Reviews                             11
# Size_MBs                         100.0
# Installs                           500
# Type                              Paid
# Price                           $15.99
# Content_Rating                Everyone
# Genres                         Medical
# Last_Updated          January 14, 2018
# Android_Ver               4.0.3 and up
# Name: 1795, dtype: object

# %%
highest_review_index = df_apps_clean['Reviews'].idxmax()
highest_review_App = df_apps_clean['App'].loc[highest_review_index]
print(f"The highest reviewd app is {highest_review_App}")
# Out:
# The highest reviewd app is Facebook

# %%
df_apps_clean.loc[highest_review_index]
# Out:
# App                         Facebook
# Category                      SOCIAL
# Rating                           4.1
# Reviews                     78158306
# Size_MBs                         5.3
# Installs               1,000,000,000
# Type                            Free
# Price                              0
# Content_Rating                  Teen
# Genres                        Social
# Last_Updated          August 3, 2018
# Android_Ver       Varies with device
# Name: 10805, dtype: object

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %% [markdown]
# **DATA VISUALIZATION**

# %%
ratings = df_apps_clean['Content_Rating'].value_counts()
print(ratings)
# Out:
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(labels=ratings, 
             values= ratings.values,
             title="Content Rating",
              names=ratings.index,
             hole = 0.5
             )
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_apps_clean.head(2)
# Out:
#                     App Category  Rating  Reviews  Size_MBs Installs  Type  \
# 21  KBA-EZ Health Guide  MEDICAL     5.0        4      25.0        1  Free
# 28             Ra Ga Ba     GAME     5.0        2      20.0        1  Paid
#
#     Price Content_Rating   Genres      Last_Updated   Android_Ver
# 21      0       Everyone  Medical    August 2, 2018  4.0.3 and up
# 28  $1.49       Everyone   Arcade  February 8, 2017    2.3 and up

# %%
df_apps_clean['Installs'].describe()
# Out:
# count          8197
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8197 entries, 21 to 10835
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   object
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   object
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
#  10  Last_Updated    8197 non-null   object
#  11  Android_Ver     8197 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         697
# 5000         425
# 10000        987
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
df_apps_clean['Price'].describe()
# Out:
# count     8197
# unique      73
# top          0
# freq      7594
# Name: Price, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8197 entries, 21 to 10835
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   int64
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   object
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
#  10  Last_Updated    8197 non-null   object
#  11  Android_Ver     8197 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].astype(str).str.replace('$',"")
df_apps_clean['Price'] = pd.to_numeric(df_apps_clean['Price'])
# Out:
# <ipython-input-113-e973c0b45038>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df_apps_clean['Price'].describe()
# Out:
# count    8197.000000
# mean        1.037576
# std        16.856860
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       400.000000
# Name: Price, dtype: float64

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean.sort_values('Price', ascending = False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL     4.6       92      32.0
# 1407               LTC AS Legal    MEDICAL     4.0        6       1.3
# 2629           I am Rich Person  LIFESTYLE     4.2      134       1.8
# 2481    A Manual of Acupuncture    MEDICAL     3.5      214      68.0
# 4264    Golfshot Plus: Golf GPS     SPORTS     4.1     3387      25.0
#
#       Installs  Type  Price Content_Rating     Genres     Last_Updated  \
# 2281      1000  Paid  79.99       Everyone    Medical    June 18, 2018
# 1407       100  Paid  39.99       Everyone    Medical    April 4, 2018
# 2629      1000  Paid  37.99       Everyone  Lifestyle    July 18, 2017
# 2481      1000  Paid  33.99       Everyone    Medical  October 2, 2017
# 4264     50000  Paid  29.99       Everyone     Sports    July 11, 2018
#
#        Android_Ver
# 2281  4.0.3 and up
# 1407    4.1 and up
# 2629  4.0.3 and up
# 2481    4.0 and up
# ...

# %%
df_apps_clean['Revenue_estimate'] = df_apps_clean['Installs'] * df_apps_clean['Price']
df_apps_clean.sort_values('Revenue_estimate', ascending = False).head()
# Out:
#                                 App     Category  Rating  Reviews   Size_MBs  \
# 9220                      Minecraft       FAMILY     4.5  2376564  19.000000
# 8825                  Hitman Sniper         GAME     4.6   408292  29.000000
# 7151  Grand Theft Auto: San Andreas         GAME     4.4   348962  26.000000
# 7977        Sleep as Android Unlock    LIFESTYLE     4.5    23966   0.851562
# 7477            Facetune - For Free  PHOTOGRAPHY     4.4    49553  48.000000
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7977   1000000  Paid   5.99       Everyone                  Lifestyle
# 7477   1000000  Paid   5.99       Everyone                Photography
#
#         Last_Updated         Android_Ver  Revenue_estimate
# ...

# %%
top_10_categories = df_apps_clean['Category'].value_counts()[:10]
top_10_categories
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# LIFESTYLE           297
# FINANCE             296
# PERSONALIZATION     296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %%
bar = px.bar(x= top_10_categories.index, y = top_10_categories.values)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs':pd.Series.sum})

# %%
category_installs.sort_values('Installs', ascending = True, inplace= True)

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

# %%
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1606   4437554490
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       296   1532341930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# ...

# %%
scatter = px.scatter(cat_merged_df, # data
                    x='App', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=cat_merged_df.index,
                    color='Installs')
 
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
 
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
